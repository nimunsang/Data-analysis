# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([1, 2, 3, 5, 8], 'red')
plt.ylabel('numbers')
plt.xlabel('plots')
plt.show()

# %%
alphabet = ['a', 'b', 'c']
values = [1, 50, 100]

plt.figure(figsize=(12, 4)) #

plt.subplot(131)
plt.bar(alphabet, values)
plt.subplot(1, 3, 2)
plt.scatter(alphabet, values)
plt.subplot(133)
plt.plot(alphabet, values)
plt.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
data = pd.read_csv("BIPA_data.csv", index_col = 0)

# %%
data1_10 = data[data['championId'].isin(range(0, 10))]
data1_10
# Out:
#             gameId           createDate tierRank position  teamId  summonerId  \
# 14      5383880007  2021-08-11 07:02:38     S352        M     200    33220626
# 36      5383880023  2021-08-11 07:13:08     G230        T     200    50160666
# 68      5383880039  2021-08-11 07:25:11     D416        M     200    82943928
# 71      5383880040  2021-08-11 07:14:33     B471        J     100     3385419
# 93      5383880046  2021-08-11 07:05:21     S120        T     200    65530457
# ...            ...                  ...      ...      ...     ...         ...
# 999897  5384659588  2021-08-11 17:10:49      P40        M     100    53140515
# 999920  5384659612  2021-08-11 17:06:30     S191        J     200     2403460
# 999935  5384659615  2021-08-11 17:12:06     G112        M     100    50060129
# 999946  5384659618  2021-08-11 17:13:59     S322        J     100    85547540
# 999954  5384659622  2021-08-11 17:11:16     G438        M     100    83418423
#
#         championId result  level  championsKilled  ...  totalDamageTaken  \
# 14               7   LOSE      9                1  ...             17659
# 36               8   LOSE     14                2  ...             21044
# 68               7    WIN     16               12  ...             21044
# 71               6   LOSE     13                2  ...             18807
# 93               8   LOSE      8                1  ...             11651
# ...            ...    ...    ...              ...  ...               ...
# 999897           4    WIN     17                9  ...             19530
# 999920           5   LOSE     12                0  ...             26321
# 999935           7    WIN     17                7  ...             23034
# 999946           5   LOSE     15                6  ...             38494
# 999954           7    WIN     17                9  ...             12988
#
#         neutralMinionsKilledEnemyJungle  neutralMinionsKilledTeamJungle  \
# 14                                    0                               2
# 36                                    0                               0
# 68                                    0                               8
# 71                                    4                              74
# 93                                    0                               0
# ...                                 ...                             ...
# 999897                                5                              25
# 999920                                0                              81
# 999935                                8                               8
# 999946                                9                              78
# 999954                                0                               8
#
#         visionScore  damageSelfMitigated  damageDealtToObjectives  \
# 14                9                 5042                        0
# 36               13                 7630                      101
# 68               26                15833                     7736
# 71               28                17689                     7497
# 93                3                 3221                        0
# ...             ...                  ...                      ...
# 999897           11                 7539                    12910
# 999920           13                11826                     7533
# 999935           25                13790                     8838
# 999946           14                36546                    19721
# 999954           25                 6521                     5189
#
#         damageDealtToTurrets    lane  gameLength         version
# 14                         0  MIDDLE        1202  11.16.390.1945
# 36                       101     TOP        1611  11.16.390.1945
# 68                      1249  MIDDLE        2156  11.16.390.1945
# 71                         0  JUNGLE        1535  11.16.390.1945
# 93                         0    NONE         930  11.16.390.1945
# ...                      ...     ...         ...             ...
# 999897                  9479  MIDDLE        1806  11.16.390.1945
# 999920                     0  JUNGLE        1548  11.16.390.1945
# 999935                  2703  MIDDLE        1868  11.16.390.1945
# 999946                     0  JUNGLE        1958  11.16.390.1945
# 999954                  5070  MIDDLE        1765  11.16.390.1945
#
# [41443 rows x 37 columns]

# %%
data1_10 = data[data['championId'].isin(range(0, 10))]
group1_10 = data1_10.groupby("championId", as_index = False).mean()
group1_10
# Out:
#    championId        gameId      teamId    summonerId      level  \
# 0           1  5.384407e+09  149.863574  4.828111e+07  13.522510
# 1           2  5.384392e+09  148.995149  5.375949e+07  13.733888
# 2           3  5.384396e+09  149.838319  5.641768e+07  12.682498
# 3           4  5.384395e+09  150.449371  4.589860e+07  13.651288
# 4           5  5.384395e+09  150.382831  4.981885e+07  13.369142
# 5           6  5.384378e+09  149.351585  4.985643e+07  14.248559
# 6           7  5.384404e+09  149.812433  5.053182e+07  13.759825
# 7           8  5.384376e+09  150.943732  5.599144e+07  14.145833
# 8           9  5.384376e+09  150.058343  4.084821e+07  13.368145
#
#    championsKilled  numDeaths    assists  neutralMinionsKilled  turretsKilled  \
# 0         5.843793   5.648704   7.482265              5.060027       0.684175
# 1         6.730423   5.649342   6.315315             98.355509       0.970201
# 2         3.223727   5.536176  10.374091              2.225748       0.415319
# 3         4.387358   5.648292   7.768424              8.230677       1.010785
# 4         6.084803   5.800812   6.957309            103.541415       0.819374
# 5         5.936599   5.662824   4.972622             14.265850       1.667867
# 6         6.782422   4.569310   6.266166              5.830922       0.622544
# 7         5.597578   5.204772   5.246617              6.983796       0.873041
# 8         5.127771   5.380688   8.717036             98.850350       0.443116
#
#    ...  totalDamageDealtToChampions  totalDamageDealt  totalDamageTaken  \
# 0  ...                 17783.212142      79020.755116      13873.920873
# 1  ...                 17017.480249     140331.489951      30216.665974
# 2  ...                 11742.800323      65968.596200      18422.628335
# 3  ...                 13840.504194     108823.763032      17346.380467
# 4  ...                 15354.615197     129307.661833      28847.416589
# 5  ...                 16819.219741     129441.371758      21756.476945
# 6  ...                 17212.238835      79998.176402      18339.237138
# 7  ...                 19073.262999     116093.556090      23501.713497
# 8  ...                 15561.794049     120797.366103      24352.407235
#
#    neutralMinionsKilledEnemyJungle  neutralMinionsKilledTeamJungle  \
# 0                         0.869031                        3.095498
# 1                         8.994456                       65.050589
# 2                         0.378941                        1.060226
# 3                         1.172858                        5.031756
# 4                         8.319606                       69.758121
# 5                         2.865994                        6.420029
# 6                         1.080475                        3.568149
# 7                         1.582265                        3.392806
# 8                         6.529463                       70.018670
#
#    visionScore  damageSelfMitigated  damageDealtToObjectives  \
# 0    23.654843          8224.886085              3825.978854
# 1    19.574498         26459.150381             18985.893278
# 2    28.201091         21981.946443              2720.986661
# 3    18.112942          8392.594368              5560.650090
# 4    20.622390         19254.804176             17998.159397
# 5    18.207493         24718.951729              9548.915706
# 6    20.033583          8599.405681              3188.190872
# 7    15.436610         11059.194979              5358.603276
# 8    48.835764         13716.184072             13164.863769
#
#    damageDealtToTurrets   gameLength
# 0           1956.866985  1644.729195
# 1           1788.160776  1635.169785
# 2           1188.933508  1622.791027
# 3           3059.980827  1590.137507
# 4           1483.745244  1612.376798
# 5           4071.570605  1637.839337
# 6           1811.963469  1629.338246
# 7           2471.168803  1609.393697
# 8            725.270128  1647.637106
#
# [9 rows x 31 columns]

# %%
#figure는 캔버스, ax는 그림의 여러 부분
fig, ax = plt.subplots(figsize = (7, 4))
ax.barh(group1_10['championId'], group1_10['totalDamageDealtToChampions'])
# Out:
# <BarContainer object of 9 artists>

# %%
#champion index 불러오기
import requests
champ_ver = requests.get('https://ddragon.leagueoflegends.com/realms/na.json').json()['n']['champion']
championJsonURL = 'http://ddragon.leagueoflegends.com/cdn/'+champ_ver+'/data/en_US/champion.json'
request = requests.get(championJsonURL)
champion_data=request.json()
champion_data.keys()
champion_dict = {}
for c_name in champion_data['data'].keys() :
    champion_dict[int(champion_data['data'][c_name]['key'])]=c_name
champion_dict.keys()
champion = pd.DataFrame.from_dict(champion_dict, orient = 'index', columns = ['champion'])

# %%
champion
# Out:
#     champion
# 266   Aatrox
# 103     Ahri
# 84     Akali
# 166   Akshan
# 12   Alistar
# ..       ...
# 238      Zed
# 115    Ziggs
# 26    Zilean
# 142      Zoe
# 143     Zyra
#
# [157 rows x 1 columns]

# %%
#champion, data merge
group1_10 = pd.merge(group1_10, champion, 
                     left_on = 'championId', right_index = True)

# %%
#y축 이름 변경
fig, ax = plt.subplots(figsize = (7, 4))
ax.barh(group1_10['champion'], 
        group1_10['totalDamageDealtToChampions'])
#         group1_10['level'])
# Out:
# <BarContainer object of 9 artists>

# %%
#dataframe에서 바로 그리기
group1_10['totalDamageDealtToChampions'].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
#인덱스 변경
group1_10.index = group1_10.champion
group1_10['totalDamageDealtToChampions'].plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='champion'>

# %%
#색상 변경(기본 설정)
sns.set_palette('bright')
fig, ax = plt.subplots(figsize = (7, 4))
ax.barh(group1_10['champion'], 
        group1_10['totalDamageDealtToChampions'])
# Out:
# <BarContainer object of 9 artists>

# %%
fig, ax = plt.subplots(figsize = (7, 4))
ax.barh(group1_10['champion'], 
        group1_10['totalDamageDealtToChampions'], color = 'red')
# Out:
# <BarContainer object of 9 artists>

# %%
#seaborn
fig, ax = plt.subplots(figsize = (7, 4))
sns.barplot(data = group1_10, x = 'totalDamageDealtToChampions', 
           y = 'champion')
# Out:
# <AxesSubplot:xlabel='totalDamageDealtToChampions', ylabel='champion'>

# %%
#xlabel, ylabel, title 변경
fig, ax = plt.subplots(figsize = (7, 4))
sns.barplot(data = group1_10, x = 'totalDamageDealtToChampions', 
           y = 'champion')
ax.set_xlabel('Avg_damage')
ax.set_ylabel('Champion Name')
ax.set_title('Avg Champion Damage')
# Out:
# Text(0.5, 1.0, 'Avg Champion Damage')

# %%
#font 변경
font_label = {
    'color' : 'blue',
    'weight' : 'bold'
}

font_title = {
    'family' : 'serif',
    'size' : 20,
    #'backgroundcolor' : black
    'color' : 'brown',
    'weight' : 'bold',
    'verticalalignment' : 'baseline',
    'horizontalalignment' : 'center'
}

fig, ax = plt.subplots(figsize = (7, 4))
sns.barplot(data = group1_10, x = 'totalDamageDealtToChampions', 
           y = 'champion')

ax.set_xlabel('Avg_damage', fontdict = font_label, labelpad = 20)
ax.set_ylabel('Champion Name', color = 'blue', labelpad = 100)
ax.set_title('Avg Champion Damage', fontdict = font_title, pad = 12)
# Out:
# Text(0.5, 1.0, 'Avg Champion Damage')

# %%
#한계선 설정
font_label = {
    'color' : 'blue',
    'weight' : 'bold'
}

font_title = {
    'family' : 'serif',
    'size' : 20,
#     'backgroundcolor' : 'black',
    'color' : 'brown',
    'weight' : 'bold',
    'verticalalignment' : 'baseline',
    'horizontalalignment' : 'center'
}

fig, ax = plt.subplots(figsize = (7, 4))
sns.barplot(data = group1_10, x = 'totalDamageDealtToChampions', 
           y = 'champion')

###
ax.set_xlim(10000, 20000)
###

ax.set_xlabel('Avg_damage', fontdict = font_label, labelpad = 20)
ax.set_ylabel('Champion Name', color = 'blue', labelpad = 20)
ax.set_title('Avg Champion Damage', fontdict = font_title, pad = 12)
# Out:
# Text(0.5, 1.0, 'Avg Champion Damage')

# %%
#한계선 설정
font_label = {
    'color' : 'blue',
    'weight' : 'bold'
}

font_title = {
    'family' : 'serif',
    'size' : 20,
#     'backgroundcolor' : 'black',
    'color' : 'brown',
    'weight' : 'bold',
    'verticalalignment' : 'baseline',
    'horizontalalignment' : 'center'
}

fig, ax = plt.subplots(figsize = (7, 4))
sns.barplot(data = group1_10, x = 'totalDamageDealtToChampions', 
           y = 'champion')
ax.set_xlim(10000, 20000)
###
damage_mean = group1_10['totalDamageDealtToChampions'].mean()
ax.axvline(damage_mean, ls = '-', lw = 3, color = 'black')
arrowprops = {
    'arrowstyle' : '->'
}
ax.annotate("average", (damage_mean, 2.5),
           xytext = (17000, 2.5), color = 'green',
           fontfamily = 'serif', fontstyle = 'italic',
           fontsize = 15, arrowprops = arrowprops)
###

ax.set_xlabel('Avg_damage', fontdict = font_label, labelpad = 20)
ax.set_ylabel('Champion Name', color = 'blue', labelpad = 20)
ax.set_title('Avg Champion Damage', fontdict = font_title, pad = 12)
# Out:
# Text(0.5, 1.0, 'Avg Champion Damage')

# %%
group_data = data[data['gameLength']>1200].groupby(
    ['position', 'championId'], as_index = False).mean()

# %%
sns.boxplot(y = data['totalDamageDealtToChampions'], 
            x = data['position'])
# Out:
# <AxesSubplot:xlabel='position', ylabel='totalDamageDealtToChampions'>

# %%
sns.violinplot(y = data['totalDamageDealtToChampions'], 
            x = data['position'])
# Out:
# <AxesSubplot:xlabel='position', ylabel='totalDamageDealtToChampions'>

# %%
sns.displot(data[data['totalDamageDealtToChampions'] < 60000]
           ['totalDamageDealtToChampions'])

# %%
sns.displot(group_data, x = 'totalDamageDealtToChampions', 
            hue = 'position')

# %%
sns.displot(group_data['totalDamageDealtToChampions'], 
            height = 4, aspect = 2)

# %%
sns.displot(group_data[group_data['position'].isin(['A', 'S'])],
            x = 'totalDamageDealtToChampions', hue = 'position',
            multiple = 'dodge', height = 4, aspect = 2)

# %%
champ_stats = pd.read_csv("champ_stats.csv")

# %%
# champ_stats.sort_values(by = 'armor', ascending = False)

# %%
sns.scatterplot(data = champ_stats, x = 'hp', y = 'hp_18')
# .set_xlim(450, 650)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='hp_18'>

# %%
plt.figure(figsize = (16, 16))
sns.scatterplot(data = champ_stats, x = 'hp', y = 'hp_18').set_xlim(450, 650)
for name in champ_stats['championName']:
    if name == 'Kled':
        continue

    plt.text(x = champ_stats[champ_stats['championName'] == name]['hp'] + 3,
            y = champ_stats[champ_stats['championName'] == name]['hp_18'] + 3,
            s = name)
