# %%
import pandas as pd
import numpy as np
import requests

# %%
# Riot Developer Portal에서 받은 API KEY입니다.
# 해당 값을 포함한 모든 종류의 KEY는 코드에 직접적으로 노출되지 않도록 하는 것이 좋습니다.
api_key = 'RGAPI-21d97aaa-2936-48f8-8d14-1b7ec8e11835'

# 본인 소환사명입니다.
summoner_name = 'bbo bbo'

# %%
# SUMMONER-V4 API URL
requesturl = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/'+summoner_name+\
'?api_key='+api_key

# %%
r = requests.get(requesturl)

# %%
# 불러온 데이터 확인
r.json()
# Out:
# {'id': 'DSE-Ry3Pe7XnkKLRszZWggYpUhzPKoSRoztg4zy4LTI-aw',
#  'accountId': '9SABmCP35rDHhLJFB4kcLRHjUhAcFWreOjTHQSYbLpq4',
#  'puuid': 'IAFEULvrkOAY3c7Q4FZMoseecg2SLCjvVNg5x2GX_sPQgczmrdlWMHwuN5gdj1ficZQzWd2bqyhk5g',
#  'name': 'bbo bbo',
#  'profileIconId': 21,
#  'revisionDate': 1633953827000,
#  'summonerLevel': 95}

# %%
# 본인 puuid입니다.
summoner_puuid = r.json()['puuid']

# %%
# 불러오고 싶은 게임 수
# 100 이하로 하기
GAME_COUNT = 50

# %%
# MATCH-V5 API URL
requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/'+summoner_puuid+\
'/ids?start=0&count='+str(GAME_COUNT)+'&api_key='+api_key

# %%
req = requests.get(requesturl)

# %%
# 불러온 데이터 확인
req.json()
# Out:
# ['KR_5506895682',
#  'KR_5506913637',
#  'KR_5506891328',
#  'KR_5506847812',
#  'KR_5506824180',
#  'KR_5506709463',
#  'KR_5502160829',
#  'KR_5478792575',
#  'KR_5478790037',
#  'KR_5478686728',
#  'KR_5467267693',
#  'KR_5467126483',
#  'KR_5467087581',
#  'KR_5467012344',
#  'KR_5466942844',
#  'KR_5466816785',
#  'KR_5466619212',
#  'KR_5466512933',
#  'KR_5466434635',
#  'KR_5466430185',
#  'KR_5465116358',
#  'KR_5465102745',
#  'KR_5464979029',
#  'KR_5464964916',
#  'KR_5464918487',
#  'KR_5464902499',
#  'KR_5452615505',
#  'KR_5452590954',
#  'KR_5452512576',
#  'KR_5452358553',
#  'KR_5452382474',
#  'KR_5452317457',
#  'KR_5449820162',
#  'KR_5449697608',
#  'KR_5449672777',
#  'KR_5428493145',
#  'KR_5428429934',
#  'KR_5428357109',
#  'KR_5413731558',
#  'KR_5385657518',
#  'KR_5374697717',
#  'KR_5374616035',
#  'KR_5366012730',
#  'KR_5365928230',
#  'KR_5365984189',
#  'KR_5351454897',
#  'KR_5351218589',
#  'KR_5351243192',
#  'KR_5337578493',
#  'KR_5337586232']

# %%
cnt = 0
special_mode = 0
blue_win = 0

for i in range(GAME_COUNT):
    matchId = req.json()[i]
    requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/'+matchId\
    +'?api_key='+api_key
    r = requests.get(requesturl)
    
    pd.set_option('display.max_columns',None)
    df = pd.DataFrame(r.json()['info']['teams'])
    
    team1_visionScore = 0
    for j in range(0, 5):
        team1_visionScore += (r.json()['info']['participants'][j]['visionScore'])
    team2_visionScore = 0
    for j in range(5, 10):
        team2_visionScore += (r.json()['info']['participants'][j]['visionScore'])
        
    print(f"\n==========game {i+1}=========\n")
    
    if r.json()['info']['gameMode'] != "CLASSIC":
        print("\n특별 게임 모드(우르프, 칼바람 등)\n")
        special_mode += 1
        continue
        
    df['team_visionScore'] = [team1_visionScore, team2_visionScore]
    COLUMNS = ['win', 'team_visionScore']
    print(df[COLUMNS])
    
    if r.json()['info']['teams'][0]['win'] == True:
        blue_win += 1
        if team1_visionScore > team2_visionScore:
            cnt += 1
    if r.json()['info']['teams'][1]['win'] == True and team2_visionScore > team1_visionScore: 
        cnt += 1
    
print(f"총 표본 : {GAME_COUNT}, 특별 게임 모드 : {special_mode}")
print(f"소환사의 협곡 {GAME_COUNT-special_mode}게임 표본에서 추출한 시야점수가 높은 팀이 이길 확률 : {cnt}/{GAME_COUNT-special_mode}")
print(f"블루팀이 이길 확률 : {blue_win}/{GAME_COUNT-special_mode}")
# Out:
# ==========game 1=========
#
#      win  team_visionScore
# 0  False               155
# 1   True               224
#
# ==========game 2=========
#
#      win  team_visionScore
# 0  False               151
# 1   True               201
#
# ==========game 3=========
#
#      win  team_visionScore
# 0  False               182
# 1   True               176
#
# ==========game 4=========
#
#      win  team_visionScore
# 0   True               102
# 1  False                80
#
# ==========game 5=========
#
#      win  team_visionScore
# 0  False               231
# 1   True               250
#
# ==========game 6=========
#
#      win  team_visionScore
# 0   True               131
# 1  False                97
#
# ==========game 7=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 8=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 9=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 10=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 11=========
#
#      win  team_visionScore
# 0   True               234
# 1  False               216
#
# ==========game 12=========
#
#      win  team_visionScore
# 0   True               100
# 1  False                87
#
# ==========game 13=========
#
#      win  team_visionScore
# 0   True               128
# 1  False               107
#
# ==========game 14=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 15=========
#
#      win  team_visionScore
# 0  False               155
# 1   True               151
#
# ==========game 16=========
#
#      win  team_visionScore
# 0   True                71
# 1  False                42
#
# ==========game 17=========
#
#      win  team_visionScore
# 0   True               133
# 1  False               129
#
# ==========game 18=========
#
#      win  team_visionScore
# 0  False               126
# 1   True               130
#
# ==========game 19=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 20=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 21=========
#
#      win  team_visionScore
# 0  False                84
# 1   True                90
#
# ==========game 22=========
#
#      win  team_visionScore
# 0  False               158
# 1   True               155
#
# ==========game 23=========
#
#      win  team_visionScore
# 0   True               121
# 1  False               101
#
# ==========game 24=========
#
#      win  team_visionScore
# 0  False                81
# 1   True               113
#
# ==========game 25=========
#
#      win  team_visionScore
# 0   True               157
# 1  False               113
#
# ==========game 26=========
#
#      win  team_visionScore
# 0   True               125
# 1  False               112
#
# ==========game 27=========
#
#      win  team_visionScore
# 0  False               167
# 1   True               185
#
# ==========game 28=========
#
#      win  team_visionScore
# 0   True                81
# 1  False                72
#
# ==========game 29=========
#
#      win  team_visionScore
# 0  False               173
# 1   True               197
#
# ==========game 30=========
#
#      win  team_visionScore
# 0   True               113
# 1  False                74
#
# ==========game 31=========
#
#      win  team_visionScore
# 0  False               167
# 1   True               145
#
# ==========game 32=========
#
#      win  team_visionScore
# 0   True               146
# 1  False               122
#
# ==========game 33=========
#
#      win  team_visionScore
# 0  False               153
# 1   True               154
#
# ==========game 34=========
#
#      win  team_visionScore
# 0   True                98
# 1  False                66
#
# ==========game 35=========
#
#      win  team_visionScore
# 0   True               141
# 1  False               140
#
# ==========game 36=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 37=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 38=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 39=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 40=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 41=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 42=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 43=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 44=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 45=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 46=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 47=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 48=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
#
# ==========game 49=========
#
#      win  team_visionScore
# 0   True                79
# 1  False                70
#
# ==========game 50=========
#
#
# 특별 게임 모드(우르프, 칼바람 등)
#
# 총 표본 : 50, 특별 게임 모드 : 21
# 소환사의 협곡 29게임 표본에서 추출한 시야점수가 높은 팀이 이길 확률 : 25/29
# 블루팀이 이길 확률 : 16/29
